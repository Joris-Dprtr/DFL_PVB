# %% [markdown]
# # Dataset loop

# %%
import numpy as np
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor

# %%
notebook_path = "./VOF_model_training.ipynb"

# %% [markdown]
# Buildings to exclude:
# 2, 6, 7, 14, 15, 18, 19

# %%
time = range(24,0,-1)
noise = [0.1,0.25,0.5,1,1.75,2.75,4]
houses = range(0,26)

# %% [markdown]
# ## building

# %%
# Read the notebook in
with open(notebook_path, "r") as f:
    notebook_content = f.read()
    for house in houses:
        # Replace the 'id' value for each iteration
        modified_notebook_content = notebook_content.replace("building = 0", f"building = {house}")
        modified_notebook_content = modified_notebook_content.replace("noise = 0.0", f"noise = {noise[0]}")

        # Create a temporary modified notebook
        modified_notebook = nbformat.reads(modified_notebook_content, as_version=nbformat.NO_CONVERT)

        # Execute the modified notebook
        execute_preprocessor = ExecutePreprocessor(timeout=-1)  # Set the timeout as needed
        try:
            execute_preprocessor.preprocess(modified_notebook)
        except:
            print(f"Error for building = {house}")
        print(f"Execution complete for building = {house}")

# %% [markdown]
# ## Hours

# %%
# Read the notebook in
with open(notebook_path, "r") as f:
    notebook_content = f.read()
    for t in time:
        # Replace the 'id' value for each iteration
        modified_notebook_content = notebook_content.replace("hours = 24", f"hours = {t}")
    
        # Create a temporary modified notebook
        modified_notebook = nbformat.reads(modified_notebook_content, as_version=nbformat.NO_CONVERT)
    
        # Execute the modified notebook
        execute_preprocessor = ExecutePreprocessor(timeout=-1)  # Set the timeout as needed
        try:
            execute_preprocessor.preprocess(modified_notebook)
        except:
            print(f"Error for hours = {t}")
        print(f"Execution complete for hours = {t}")
# Out:
# Execution complete for hours = 24
# Execution complete for hours = 23

# %% [markdown]
# ## Noise

# %%
# Read the notebook in
with open(notebook_path, "r") as f:
    notebook_content = f.read()
    for n in noise:
        value = round(n,2)
        # Replace the 'id' value for each iteration
        modified_notebook_content = notebook_content.replace("noise = 0.0", f"noise = {value}")

        # Create a temporary modified notebook
        modified_notebook = nbformat.reads(modified_notebook_content, as_version=nbformat.NO_CONVERT)

        # Execute the modified notebook
        execute_preprocessor = ExecutePreprocessor(timeout=-1)  # Set the timeout as needed
        try:
            execute_preprocessor.preprocess(modified_notebook)
        except:
            print(f"Error for noise = {value}")
        print(f"Execution complete for noise = {value}")
