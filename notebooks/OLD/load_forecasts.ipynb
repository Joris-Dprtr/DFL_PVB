# %%
building = 26
price = 'Realistic'
noise = 4

# %%
import numpy as np
import src.data.dataprep as prep
from src.util.open_meteo_api import simulate_forecast as sim

# %%
# Import the base data and resample it from 5 minutes to hourly
nl_data = prep.dutch_data('../data/Dutchdata_clean/building_' + str(building) + '.parquet', 'h', price=price)

# %%
load_fcst = sim(nl_data['load'], noise_scale=noise, skewness=-0.5, smooth_param=0.5)
# Out:
# C:\Users\joris\Projects\PVB_VOF\src\util\open_meteo_api.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   shifted[new_i] = series[i]
# C:\Users\joris\Projects\PVB_VOF\src\util\open_meteo_api.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   shifted[i] = series[i]

# %%
np.save('../data/load_fcsts/building_' + str(building) + '_' + str(noise) + '_noise_forecast.npy', load_fcst)
