# %% [markdown]
# # Dataset loop

# %%
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor

# %%
notebook_path = "./load_error_lstms.ipynb"

# %%
building_values = range(1,27)

# %%
# Read the notebook in
with open(notebook_path, "r") as f:
    notebook_content = f.read()
    for building_value in building_values:
        # Replace the 'id' value for each iteration
        modified_notebook_content = notebook_content.replace("building = 0", f"building = {building_value}")
    
        # Create a temporary modified notebook
        modified_notebook = nbformat.reads(modified_notebook_content, as_version=nbformat.NO_CONVERT)
    
        # Execute the modified notebook
        execute_preprocessor = ExecutePreprocessor(timeout=-1)  # Set the timeout as needed
        try:
            execute_preprocessor.preprocess(modified_notebook)
        except:
            print(f"Error for building={building_value}")
        print(f"Execution complete for building={building_value}")
# Out:
# Execution complete for building=1
# Execution complete for building=2
# Execution complete for building=3
# Execution complete for building=4
# Execution complete for building=5
# Execution complete for building=6
# Execution complete for building=7
# Execution complete for building=8
# Execution complete for building=9
# Execution complete for building=10
# Execution complete for building=11
# Execution complete for building=12
# Execution complete for building=13
# Execution complete for building=14
# Execution complete for building=15
# Execution complete for building=16
# Execution complete for building=17
# Execution complete for building=18
# Execution complete for building=19
# Execution complete for building=20
# Execution complete for building=21
# Execution complete for building=22
# Execution complete for building=23
# Execution complete for building=24
# Execution complete for building=25
