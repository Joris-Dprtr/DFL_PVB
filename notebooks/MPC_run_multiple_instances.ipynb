# %% [markdown]
# # Dataset loop

# %%
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor

# %%
notebook_path = "./MPC_main_notebook_limited.ipynb"

# %% [markdown]
# Buildings to exclude:
# building_2
# building_6
# building_7
# building_14
# building_15
# building_18
# building_19

# %%
kwh_list = [0.5,1,1.5,2,2.5,3]
#building = range(16,18)

# %%
# Read the notebook in
with open(notebook_path, "r") as f:
    notebook_content = f.read()
    for kwh in kwh_list:
        # Replace the 'id' value for each iteration
        modified_notebook_content = notebook_content.replace("kwh_bat = 0.5", f"kwh_bat = {kwh}")
    
        # Create a temporary modified notebook
        modified_notebook = nbformat.reads(modified_notebook_content, as_version=nbformat.NO_CONVERT)
    
        # Execute the modified notebook
        execute_preprocessor = ExecutePreprocessor(timeout=-1)  # Set the timeout as needed
        try:
            execute_preprocessor.preprocess(modified_notebook)
        except:
            print(f"Error for hours = {kwh}")
        print(f"Execution complete for hours = {kwh}")
# Out:
# Execution complete for hours = 0.5
# Execution complete for hours = 1
# Execution complete for hours = 1.5
# Execution complete for hours = 2
# Execution complete for hours = 2.5
