# %% [markdown]
# # Dataset loop

# %%
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor

# %%
notebook_path = "./MPC_main_notebook.ipynb"

# %% [markdown]
# Buildings to exclude:
# building_2
# building_6
# building_7
# building_14
# building_15
# building_18
# building_19

# %%
time = range(21,0,-1)

# %%
# Read the notebook in
with open(notebook_path, "r") as f:
    notebook_content = f.read()
    for t in time:
        # Replace the 'id' value for each iteration
        modified_notebook_content = notebook_content.replace("time = 24", f"time = {t}")
    
        # Create a temporary modified notebook
        modified_notebook = nbformat.reads(modified_notebook_content, as_version=nbformat.NO_CONVERT)
    
        # Execute the modified notebook
        execute_preprocessor = ExecutePreprocessor(timeout=-1)  # Set the timeout as needed
        try:
            execute_preprocessor.preprocess(modified_notebook)
        except:
            print(f"Error for hours = {t}")
        print(f"Execution complete for hours = {t}")
# Out:
# Execution complete for hours = 21
# Execution complete for hours = 20
# Execution complete for hours = 19
# Execution complete for hours = 18
# Execution complete for hours = 17
# Execution complete for hours = 16
# Execution complete for hours = 15
# Execution complete for hours = 14
# Execution complete for hours = 13
# Execution complete for hours = 12
# Execution complete for hours = 11
# Execution complete for hours = 10
# Execution complete for hours = 9
# Execution complete for hours = 8
# Execution complete for hours = 7
# Execution complete for hours = 6
# Execution complete for hours = 5
# Execution complete for hours = 4
# Execution complete for hours = 3
# Execution complete for hours = 2
# Execution complete for hours = 1
